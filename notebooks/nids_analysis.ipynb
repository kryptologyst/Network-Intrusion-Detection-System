# %% [markdown]
# # Network Intrusion Detection System - Analysis Notebook
#
# This notebook demonstrates the Network Intrusion Detection System (NIDS) for security research and education.
#
# ## ⚠️ DISCLAIMER
#
# **This is a research and educational demonstration. It is NOT intended for production security operations.**

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Import NIDS modules
from src.data.processor import SyntheticDataGenerator, NetworkFlowDataProcessor
from src.features.engineer import NetworkFlowFeatureEngineer
from src.models.models import ModelFactory
from src.eval.evaluator import NIDSEvaluator
from src.utils.utils import set_random_seeds, setup_logging

# Set up logging and random seeds
logger = setup_logging()
set_random_seeds(42)

# Set plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")
